# %%
import matplotlib.pyplot as pyplot
import os, sys
import numpy as np
import json

# %%
with open('solar_spectrum_E490_AM0_dataset.dat', 'r') as f:
    lines = f.readlines()

# %%
def map_line(l):
    l = map(str.strip, l.split())
    l = map(float, l)
    return l
data = map(map_line, lines)
data = np.asarray(data)

# %%
mask = np.bitwise_and(data[:,0]>0.300, data[:,0]<0.800)
spectrum = data[mask,:]
spectrum[:,0] *= 1000.

# %%
# %matplotlib inline

# %%
pyplot.plot(spectrum[:,0], spectrum[:,1])

# %%
bin_boundaries = np.linspace(380., 720., 11)
print bin_boundaries
print bin_boundaries.shape
bin_centers = np.average([bin_boundaries[1:], bin_boundaries[:-1]], axis=0)
print bin_centers
# Out:
# [ 380.  414.  448.  482.  516.  550.  584.  618.  652.  686.  720.]
# (11,)
# [ 397.  431.  465.  499.  533.  567.  601.  635.  669.  703.]

# %%
downsampled, _ = np.histogram(spectrum[:, 0], bins = bin_boundaries, weights = spectrum[:,1])
counts,_       = np.histogram(spectrum[:, 0], bins = bin_boundaries)
print downsampled
print counts
downsampled /= counts
# Out:
# [ 45168.  59014.  68746.  65219.  63085.  62726.  59682.  38170.  25810.
#   23880.]
# [34 34 34 34 34 34 34 23 17 17]

# %%
pyplot.ioff()
pyplot.bar(bin_boundaries[:-1], downsampled, bin_boundaries[1:]-bin_boundaries[:-1])
pyplot.plot(spectrum[:,0], spectrum[:,1], color = 'r')
pyplot.draw()

# %%
normalized = downsampled / np.sum(downsampled)
print '{ '+', '.join(map(str, normalized))+' }'
# Out:
# { 0.0779504233435, 0.101845693482, 0.118641068969, 0.112554212275, 0.10887137922, 0.108251821082, 0.102998520324, 0.0973780017468, 0.0890852119419, 0.0824236676161 }
